# %% [markdown]
# # Data Generation
#
# ### Short prompt => interactive calm story
#
# Here data get generated by GPT-3.5 for an GPT2 model which will be fine-tuned with the data as calm down bot, to boosting your mind.
#
# - english
# - dialog
# - topic: boosting and relaxing

# %%
import numpy as np
import pandas as pd

import os
import pyperclip

import keyboard

import pickle
from datetime import datetime as dt

# %% [markdown]
# ### OpenAI ChatGPT API Integreation

# %%
from openai import OpenAI

with open("./API_KEY.txt", "r") as f:
  API_KEY = f.read()
client = OpenAI(api_key=API_KEY)

def request_gpt3(message):
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": message}
    ]

    response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=messages
    )

    #return response
    return response.choices[0].message.content

# %% [markdown]
# ### Create Traindata
#
# create commands for ChatGPT for Data generation

# %%
first_part = f"Create a dialog between 2 people. The first is the user and the other is the storyteller. \
The storyteller wants to create a interesting, exciting and calming story. \
The goal is to bring the user to positive thoughts and calm him a bit down."

# %%
second_part = [
    "japanese garden",
    "express",
    "mountain",
    "forest clearing",
    "cave",
    "meadow",
    "outer-space",
    "hot-air-balloon",
    "christmas",
    "home",
    "ocean",
    "beach"
    "lake",
    "castle",
    "stream",
    "magic",
    "garden",
    "shopping mall",
    "medieval",
    "dinosaurs",
    "church",
    "adventure park",
    "zoo",
    "north pole",
    "other planet",
    "past",
    "timetravel",
    "flying",
    "clouds",
    "underwater world",
    "city in the sky",
    "atlantis",
    "heaven",
    "valhalla",
    "super mario world",
    "pokemon world",
    "chinese tempel",
    "travel around the world",
    "timeless bubble",
    "magic castle",
    "treehouse",
    "stone age",
    "whirlpool",
    "walking on the sun",
    "living on moon",
    "desert",
    "ice Storm",
    "in glacier",
    "vulcano",
    "chocolate factory",
    "super powers",
    "cave full of shiny jewels",
    "rainforest",
    "carnival",
    "haunted house",
    "art gallery",
    "amusement park",
    "aquarium",
    "planetarium",
    "rainbow",
    "circus",
    "futuristic city",
    "waterfall",
    "mountain lake",
    "coral reef",
    "safari",
    "starry sky",
    "enchanted forest",
    "cathedral",
    "fairy tale forest",
    "giants castle",
    "haunted mansion",
    "ice palace",
    "jungle temple",
    "fireplace",
    "gold cave",
    "mermaid lagoon",
    "rainbow bridge",
    "balcony with city view",
    "volcano island",
    "dinosaur island",
    "candy island",
    "space station",
    "zen garden",
    "xanadu city",
    "mythical creature",
    "mythical tempel",
    "witch cottage",
    "underwater cave"
]

# %%
third_part = ["It should be a meditative and calming story. A interactive mindful story with much details.",
                "It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.",
                "It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.",
                "It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story."]

# %%
post_adding = "Write only the Dialog no other message. Write the dialog on english and use following format:\nPerson A: ... \nPerson B: ... \nPerson A: ... \n..."

# %%
def create_new_file(content=""):
    file_name = "01_conversation.txt"
    i = 1
    while file_name in os.listdir("./data/"):
        i += 1
        file_name = f"{i:02d}_conversation.txt"
    with open(f"./data/{file_name}", "w") as f:
        f.write(content)

def get_newest_file(as_number=True):
    file_name = "01_conversation.txt"
    i = 1
    while file_name in os.listdir("./data/"):
        i += 1
        file_name = f"{i:02d}_conversation.txt"
    if as_number:
        return i
    else:
        return file_name

def should_generate_file(counter, old_file_number):
    return f"{old_file_number:02d}_conversation.txt", f"{old_file_number+counter:02d}_conversation.txt"

def get_random_elem(x):
    return np.random.choice(x, 1)[0]

def save_as_pickle(name:str, content):
    with open(f"./{name}.pickle", "wb") as file:
        pickle.dump(content, file)

def load_pickle(name:str):
    with open(f"./{name}.pickle", "rb") as file:
        return pickle.load(file)

def get_informations(counter, duration):
    """Returns a dict of informations"""
    info = dict()
    info["time_date"] = dt.now().strftime("%d.%m.%Y %H:%M:%S")
    info["date"] = dt.now().date().strftime("%d.%m.%Y")
    info["time"] = dt.now().strftime("%H:%M:%S")
    info["n_commmands"] = counter
    info["duration"] = duration
    return info

# %%
# load pickle files (logs)
try:
    executed_commands = load_pickle("executed_commands_stories")
except Exception:
    executed_commands = dict()

try:
    information = load_pickle("information_stories")
except Exception:
    information = dict()

# %%
counter = 0
start = dt.now()
file_num = get_newest_file()
should_run = True

with open("./stop.txt", "w") as f:
    f.write("0")

while should_run:
    counter += 1
    command = ""

    # add first part
    command += first_part

    # add second part
    word = get_random_elem(second_part)
    command += f"\nThe topic of the story should be: {word}. The first message from the user is just the word {word}."

    # add third part
    command += f"\n{get_random_elem(third_part)}"

    # add post part
    command += f"\n{post_adding}"

    # pyperclip.copy(command)
    # print("\nCommand is copied!\n")

    print(f"\"ChatGPT data generation command:\n{command}\"")

    response = request_gpt3(command)
    create_new_file(response)
    if command in executed_commands.keys():
        executed_commands[command] += 1
    else:
        executed_commands[command] = 1

    with open("./stop.txt", "r") as f:
        if f.read() != "0":
            should_run = False
        
print("\n  -----> Loop stopped because a key was pressed <------")
end = dt.now()

from_, to_ = should_generate_file(counter, file_num)
print(f"\n\nShould Generated {counter} new files.\n    {from_} -> {to_}")

# Statistics
duration = abs((start-end).total_seconds())
cur_info = get_informations(counter, duration)
information[cur_info["time_date"]] = cur_info
save_as_pickle("information", information)

save_as_pickle("executed_commands", executed_commands)
# Out:
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: chocolate factory. The first message from the user is just the word chocolate factory.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: art gallery. The first message from the user is just the word art gallery.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: rainbow bridge. The first message from the user is just the word rainbow bridge.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timetravel. The first message from the user is just the word timetravel.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: japanese garden. The first message from the user is just the word japanese garden.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timeless bubble. The first message from the user is just the word timeless bubble.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: clouds. The first message from the user is just the word clouds.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: gold cave. The first message from the user is just the word gold cave.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: mermaid lagoon. The first message from the user is just the word mermaid lagoon.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
#
#   -----> Loop stopped because a key was pressed <------
#
#
# Should Generated 9 new files.
#     3609_conversation.txt -> 3618_conversation.txt

# %% [markdown]
# **-> For Stopping, change text in stop.txt**

# %% [markdown]
# **General Stats**

# %%
try:
    information = load_pickle("information_stories")
except Exception:
    raise ValueError("No Log Files Yet!")

# %%
sorted_dict = dict(sorted(information.items(), key=lambda x: dt.strptime(x[0], '%d.%m.%Y %H:%M:%S')))
total_seconds = 0
total_commands = 0
for key, value in sorted_dict.items():
    print(f"\n{key}")
    for key_2, value_2 in value.items():
        print(f"   - {key_2}: {value_2}")
    total_seconds += float(value["duration"])
    total_commands += float(value["n_commmands"])
# Out:
# 23.12.2023 18:46:37
#    - time_date: 23.12.2023 18:46:37
#    - date: 23.12.2023
#    - time: 18:46:37
#    - n_commmands: 62
#    - duration: 806.838947
#
# 23.12.2023 20:12:52
#    - time_date: 23.12.2023 20:12:52
#    - date: 23.12.2023
#    - time: 20:12:52
#    - n_commmands: 357
#    - duration: 4312.139409
#
# 23.12.2023 22:45:41
#    - time_date: 23.12.2023 22:45:41
#    - date: 23.12.2023
#    - time: 22:45:41
#    - n_commmands: 694
#    - duration: 7799.659912
#
# 23.12.2023 23:36:10
#    - time_date: 23.12.2023 23:36:10
#    - date: 23.12.2023
#    - time: 23:36:10
#    - n_commmands: 268
#    - duration: 2833.619477
#
# 24.12.2023 15:05:18
#    - time_date: 24.12.2023 15:05:18
#    - date: 24.12.2023
#    - time: 15:05:18
#    - n_commmands: 1419
#    - duration: 23795.164321
#
# 25.12.2023 22:02:11
#    - time_date: 25.12.2023 22:02:11
#    - date: 25.12.2023
#    - time: 22:02:11
#    - n_commmands: 749
#    - duration: 17051.554415
#
# 25.12.2023 22:06:29
#    - time_date: 25.12.2023 22:06:29
#    - date: 25.12.2023
#    - time: 22:06:29
#    - n_commmands: 9
#    - duration: 193.679337

# %%
minutes, seconds = divmod(total_seconds, 60)
hours, minutes = divmod(minutes, 60)
days, hours = divmod(hours, 24)
print(f"Total traindata creation time:\n    -> {int(days)} Days\n    -> {int(hours)} Hours\n    -> {int(minutes)} Minutes\n    -> {int(seconds)} Seconds");
print(f"\nRunned Commands: {int(total_commands)}");
# Out:
# Total traindata creation time:
#     -> 0 Days
#     -> 15 Hours
#     -> 46 Minutes
#     -> 32 Seconds
#
# Runned Commands: 3558

# %% [markdown]
# **Command Stats:**

# %%
try:
    executed_commands = load_pickle("executed_commands_stories")
except Exception:
    raise ValueError("No Log Files Yet!")

# %% [markdown]
# Runned Commands

# %%
count = 0
for key, value in executed_commands.items():
    count += value

print(f"Created {count} Training-Dialogs.")
# Out:
# Created 3558 Training-Dialogs.

# %% [markdown]
# Unique Commands

# %%
[print(f"\n{'-'*16}\n{i}") for i in executed_commands.keys()];
# Out:
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean. The first message from the user is just the word ocean.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: chocolate factory. The first message from the user is just the word chocolate factory.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stone age. The first message from the user is just the word stone age.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest clearing. The first message from the user is just the word forest clearing.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: city in the sky. The first message from the user is just the word city in the sky.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon. The first message from the user is just the word hot-air-balloon.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: pokemon world. The first message from the user is just the word pokemon world.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stone age. The first message from the user is just the word stone age.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream. The first message from the user is just the word stream.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ice Storm. The first message from the user is just the word ice Storm.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave. The first message from the user is just the word cave.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic castle. The first message from the user is just the word magic castle.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: vulcano. The first message from the user is just the word vulcano.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space. The first message from the user is just the word outer-space.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: japanese garden. The first message from the user is just the word japanese garden.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: whirlpool. The first message from the user is just the word whirlpool.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timeless bubble. The first message from the user is just the word timeless bubble.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: flying. The first message from the user is just the word flying.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle. The first message from the user is just the word castle.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stone age. The first message from the user is just the word stone age.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: chocolate factory. The first message from the user is just the word chocolate factory.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: super mario world. The first message from the user is just the word super mario world.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: home. The first message from the user is just the word home.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: treehouse. The first message from the user is just the word treehouse.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: pokemon world. The first message from the user is just the word pokemon world.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: living on moon. The first message from the user is just the word living on moon.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: vulcano. The first message from the user is just the word vulcano.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: home. The first message from the user is just the word home.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: medieval. The first message from the user is just the word medieval.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: walking on the sun. The first message from the user is just the word walking on the sun.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: express. The first message from the user is just the word express.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: treehouse. The first message from the user is just the word treehouse.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ice Storm. The first message from the user is just the word ice Storm.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave. The first message from the user is just the word cave.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timetravel. The first message from the user is just the word timetravel.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: shopping mall. The first message from the user is just the word shopping mall.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet. The first message from the user is just the word other planet.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: beachlake. The first message from the user is just the word beachlake.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: past. The first message from the user is just the word past.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: adventure park. The first message from the user is just the word adventure park.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: beachlake. The first message from the user is just the word beachlake.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon. The first message from the user is just the word hot-air-balloon.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle. The first message from the user is just the word castle.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: valhalla. The first message from the user is just the word valhalla.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream. The first message from the user is just the word stream.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: past. The first message from the user is just the word past.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: valhalla. The first message from the user is just the word valhalla.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: clouds. The first message from the user is just the word clouds.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: travel around the world. The first message from the user is just the word travel around the world.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: home. The first message from the user is just the word home.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: valhalla. The first message from the user is just the word valhalla.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: clouds. The first message from the user is just the word clouds.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: giants castle. The first message from the user is just the word giants castle.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: xanadu city. The first message from the user is just the word xanadu city.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: rainbow. The first message from the user is just the word rainbow.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: starry sky. The first message from the user is just the word starry sky.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: dinosaur island. The first message from the user is just the word dinosaur island.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: jungle temple. The first message from the user is just the word jungle temple.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space. The first message from the user is just the word outer-space.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: volcano island. The first message from the user is just the word volcano island.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: fairy tale forest. The first message from the user is just the word fairy tale forest.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: planetarium. The first message from the user is just the word planetarium.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas. The first message from the user is just the word christmas.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo. The first message from the user is just the word zoo.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: walking on the sun. The first message from the user is just the word walking on the sun.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: balcony with city view. The first message from the user is just the word balcony with city view.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: planetarium. The first message from the user is just the word planetarium.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: carnival. The first message from the user is just the word carnival.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream. The first message from the user is just the word stream.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: atlantis. The first message from the user is just the word atlantis.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: underwater world. The first message from the user is just the word underwater world.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: dinosaur island. The first message from the user is just the word dinosaur island.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: futuristic city. The first message from the user is just the word futuristic city.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: heaven. The first message from the user is just the word heaven.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# ...
# The topic of the story should be: rainbow bridge. The first message from the user is just the word rainbow bridge.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: living on moon. The first message from the user is just the word living on moon.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: space station. The first message from the user is just the word space station.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: underwater cave. The first message from the user is just the word underwater cave.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: volcano island. The first message from the user is just the word volcano island.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: in glacier. The first message from the user is just the word in glacier.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: starry sky. The first message from the user is just the word starry sky.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: art gallery. The first message from the user is just the word art gallery.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: candy island. The first message from the user is just the word candy island.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: city in the sky. The first message from the user is just the word city in the sky.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: haunted house. The first message from the user is just the word haunted house.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave. The first message from the user is just the word cave.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: desert. The first message from the user is just the word desert.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: jungle temple. The first message from the user is just the word jungle temple.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: underwater cave. The first message from the user is just the word underwater cave.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: volcano island. The first message from the user is just the word volcano island.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo. The first message from the user is just the word zoo.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: in glacier. The first message from the user is just the word in glacier.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas. The first message from the user is just the word christmas.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: candy island. The first message from the user is just the word candy island.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: balcony with city view. The first message from the user is just the word balcony with city view.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: north pole. The first message from the user is just the word north pole.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave full of shiny jewels. The first message from the user is just the word cave full of shiny jewels.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: amusement park. The first message from the user is just the word amusement park.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest clearing. The first message from the user is just the word forest clearing.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...

# %% [markdown]
# All Commands

# %%
print("All executed Commands:")
sorted_commands = dict(sorted(executed_commands.items(), key=lambda x:x[1], reverse=False))
for key, value in sorted_commands.items():
    print(f"{'-'*16}\nAmount: {value}\nCommand:\n{key}")
# Out:
# All executed Commands:
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean. The first message from the user is just the word ocean.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: church. The first message from the user is just the word church.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: rainbow bridge. The first message from the user is just the word rainbow bridge.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cathedral. The first message from the user is just the word cathedral.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: desert. The first message from the user is just the word desert.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: north pole. The first message from the user is just the word north pole.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: enchanted forest. The first message from the user is just the word enchanted forest.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: space station. The first message from the user is just the word space station.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: enchanted forest. The first message from the user is just the word enchanted forest.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave full of shiny jewels. The first message from the user is just the word cave full of shiny jewels.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: haunted mansion. The first message from the user is just the word haunted mansion.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: fireplace. The first message from the user is just the word fireplace.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: haunted house. The first message from the user is just the word haunted house.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: candy island. The first message from the user is just the word candy island.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space. The first message from the user is just the word outer-space.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: home. The first message from the user is just the word home.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream. The first message from the user is just the word stream.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: circus. The first message from the user is just the word circus.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: fireplace. The first message from the user is just the word fireplace.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: vulcano. The first message from the user is just the word vulcano.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ice palace. The first message from the user is just the word ice palace.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: xanadu city. The first message from the user is just the word xanadu city.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: flying. The first message from the user is just the word flying.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: waterfall. The first message from the user is just the word waterfall.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas. The first message from the user is just the word christmas.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave full of shiny jewels. The first message from the user is just the word cave full of shiny jewels.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: chinese tempel. The first message from the user is just the word chinese tempel.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: underwater cave. The first message from the user is just the word underwater cave.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: balcony with city view. The first message from the user is just the word balcony with city view.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: futuristic city. The first message from the user is just the word futuristic city.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: desert. The first message from the user is just the word desert.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: desert. The first message from the user is just the word desert.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space. The first message from the user is just the word outer-space.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: rainbow bridge. The first message from the user is just the word rainbow bridge.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: space station. The first message from the user is just the word space station.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: in glacier. The first message from the user is just the word in glacier.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave. The first message from the user is just the word cave.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas. The first message from the user is just the word christmas.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: amusement park. The first message from the user is just the word amusement park.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 6
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest clearing. The first message from the user is just the word forest clearing.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: planetarium. The first message from the user is just the word planetarium.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas. The first message from the user is just the word christmas.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo. The first message from the user is just the word zoo.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: walking on the sun. The first message from the user is just the word walking on the sun.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: underwater world. The first message from the user is just the word underwater world.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: witch cottage. The first message from the user is just the word witch cottage.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic castle. The first message from the user is just the word magic castle.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: waterfall. The first message from the user is just the word waterfall.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: circus. The first message from the user is just the word circus.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: volcano island. The first message from the user is just the word volcano island.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: giants castle. The first message from the user is just the word giants castle.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: garden. The first message from the user is just the word garden.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: aquarium. The first message from the user is just the word aquarium.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet. The first message from the user is just the word other planet.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: rainbow. The first message from the user is just the word rainbow.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: medieval. The first message from the user is just the word medieval.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: super mario world. The first message from the user is just the word super mario world.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: mythical tempel. The first message from the user is just the word mythical tempel.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: dinosaurs. The first message from the user is just the word dinosaurs.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: past. The first message from the user is just the word past.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ice Storm. The first message from the user is just the word ice Storm.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: mythical creature. The first message from the user is just the word mythical creature.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic castle. The first message from the user is just the word magic castle.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: haunted mansion. The first message from the user is just the word haunted mansion.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: space station. The first message from the user is just the word space station.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: heaven. The first message from the user is just the word heaven.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: valhalla. The first message from the user is just the word valhalla.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: mermaid lagoon. The first message from the user is just the word mermaid lagoon.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: garden. The first message from the user is just the word garden.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timeless bubble. The first message from the user is just the word timeless bubble.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: express. The first message from the user is just the word express.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: haunted house. The first message from the user is just the word haunted house.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 7
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: jungle temple. The first message from the user is just the word jungle temple.
# ...
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 14
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: underwater cave. The first message from the user is just the word underwater cave.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave. The first message from the user is just the word cave.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle. The first message from the user is just the word castle.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: travel around the world. The first message from the user is just the word travel around the world.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: valhalla. The first message from the user is just the word valhalla.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: starry sky. The first message from the user is just the word starry sky.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: north pole. The first message from the user is just the word north pole.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space. The first message from the user is just the word outer-space.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cathedral. The first message from the user is just the word cathedral.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: adventure park. The first message from the user is just the word adventure park.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: jungle temple. The first message from the user is just the word jungle temple.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: amusement park. The first message from the user is just the word amusement park.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 15
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: starry sky. The first message from the user is just the word starry sky.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 16
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean. The first message from the user is just the word ocean.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 16
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: atlantis. The first message from the user is just the word atlantis.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 16
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: chinese tempel. The first message from the user is just the word chinese tempel.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 16
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: rainbow bridge. The first message from the user is just the word rainbow bridge.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 16
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: meadow. The first message from the user is just the word meadow.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 16
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean. The first message from the user is just the word ocean.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 17
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: shopping mall. The first message from the user is just the word shopping mall.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 17
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: atlantis. The first message from the user is just the word atlantis.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 18
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stone age. The first message from the user is just the word stone age.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 19
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: jungle temple. The first message from the user is just the word jungle temple.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 21
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: express. The first message from the user is just the word express.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...

# %% [markdown]
# ---
