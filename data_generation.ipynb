# %% [markdown]
# # Data Generation
#
# ### Short prompt => interactive calm story
#
# Here data get generated by GPT-3.5 for an GPT2 model which will be fine-tuned with the data as calm down bot, to boosting your mind.
#
# - english
# - dialog
# - topic: boosting and relaxing

# %%
import numpy as np
import pandas as pd

import os
import pyperclip

import keyboard

import pickle
from datetime import datetime as dt

# %% [markdown]
# ### OpenAI ChatGPT API Integreation

# %%
from openai import OpenAI

with open("./API_KEY.txt", "r") as f:
  API_KEY = f.read()
client = OpenAI(api_key=API_KEY)

def request_gpt3(message):
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": message}
    ]

    response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=messages
    )

    #return response
    return response.choices[0].message.content

# %% [markdown]
# ### Create Traindata
#
# create commands for ChatGPT for Data generation

# %%
first_part = f"Create a dialog between 2 people. The first is the user and the other is the storyteller. \
The storyteller wants to create a interesting, exciting and calming story. \
The goal is to bring the user to positive thoughts and calm him a bit down."

# %%
second_part = [
    "japanese garden",
    "express",
    "mountain",
    "forest clearing",
    "cave",
    "meadow",
    "outer-space",
    "hot-air-balloon",
    "christmas",
    "home",
    "ocean",
    "beach"
    "lake",
    "castle",
    "stream",
    "magic",
    "garden",
    "shopping mall",
    "medieval",
    "dinosaurs",
    "church",
    "adventure park",
    "zoo",
    "north pole",
    "other planet",
    "past",
    "timetravel",
    "flying",
    "clouds",
    "underwater world",
    "city in the sky",
    "atlantis",
    "heaven",
    "valhalla",
    "super mario world",
    "pokemon world",
    "chinese tempel",
    "travel around the world",
    "timeless bubble",
    "magic castle",
    "treehouse",
    "stone age",
    "whirlpool",
    "walking on the sun",
    "living on moon",
    "desert",
    "ice Storm",
    "in glacier",
    "vulcano",
    "chocolate factory",
    "super powers",
    "cave full of shiny jewels"
]

# %%
third_part = ["It should be a meditative and calming story. A interactive mindful story with much details.",
                "It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.",
                "It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.",
                "It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story."]

# %%
post_adding = "Write only the Dialog no other message. Write the dialog on english and use following format:\nPerson A: ... \nPerson B: ... \nPerson A: ... \n..."

# %%
def create_new_file(content=""):
    file_name = "01_conversation.txt"
    i = 1
    while file_name in os.listdir("./data/"):
        i += 1
        file_name = f"{i:02d}_conversation.txt"
    with open(f"./data/{file_name}", "w") as f:
        f.write(content)

def get_newest_file(as_number=True):
    file_name = "01_conversation.txt"
    i = 1
    while file_name in os.listdir("./data/"):
        i += 1
        file_name = f"{i:02d}_conversation.txt"
    if as_number:
        return i
    else:
        return file_name

def should_generate_file(counter, old_file_number):
    return f"{old_file_number:02d}_conversation.txt", f"{old_file_number+counter:02d}_conversation.txt"

def get_random_elem(x):
    return np.random.choice(x, 1)[0]

def save_as_pickle(name:str, content):
    with open(f"./{name}.pickle", "wb") as file:
        pickle.dump(content, file)

def load_pickle(name:str):
    with open(f"./{name}.pickle", "rb") as file:
        return pickle.load(file)

def get_informations(counter, duration):
    """Returns a dict of informations"""
    info = dict()
    info["time_date"] = dt.now().strftime("%d.%m.%Y %H:%M:%S")
    info["date"] = dt.now().date().strftime("%d.%m.%Y")
    info["time"] = dt.now().strftime("%H:%M:%S")
    info["n_commmands"] = counter
    info["duration"] = duration
    return info

# %%
# load pickle files (logs)
try:
    executed_commands = load_pickle("executed_commands")
except Exception:
    executed_commands = dict()

try:
    information = load_pickle("information")
except Exception:
    information = dict()

# %%
counter = 0
start = dt.now()
file_num = get_newest_file()
should_run = True

with open("./stop.txt", "w") as f:
    f.write("0")

while should_run:
    counter += 1
    command = ""

    # add first part
    command += first_part

    # add second part
    word = get_random_elem(second_part)
    command += f"\nThe topic of the story should be: {word}. The first message from the user is just the word {word}."

    # add third part
    command += f"\n{get_random_elem(third_part)}"

    # add post part
    command += f"\n{post_adding}"

    # pyperclip.copy(command)
    # print("\nCommand is copied!\n")

    print(f"\"ChatGPT data generation command:\n{command}\"")

    response = request_gpt3(command)
    create_new_file(response)
    if command in executed_commands.keys():
        executed_commands[command] += 1
    else:
        executed_commands[command] = 1

    with open("./stop.txt", "r") as f:
        if f.read() != "0":
            should_run = False
        
print("\n  -----> Loop stopped because a key was pressed <------")
end = dt.now()

from_, to_ = should_generate_file(counter, file_num)
print(f"\n\nShould Generated {counter} new files.\n    {from_} -> {to_}")

# Statistics
duration = abs((start-end).total_seconds())
cur_info = get_informations(counter, duration)
information[cur_info["time_date"]] = cur_info
save_as_pickle("information", information)

save_as_pickle("executed_commands", executed_commands)
# Out:
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean. The first message from the user is just the word ocean.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: chocolate factory. The first message from the user is just the word chocolate factory.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stone age. The first message from the user is just the word stone age.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest clearing. The first message from the user is just the word forest clearing.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: city in the sky. The first message from the user is just the word city in the sky.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."
# "ChatGPT data generation command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon. The first message from the user is just the word hot-air-balloon.
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ..."

# %% [markdown]
# **-> For Stopping, change text in stop.txt**

# %% [markdown]
# **General Stats**

# %%
try:
    information = load_pickle("information")
except Exception:
    raise ValueError("No Log Files Yet!")

# %%
sorted_dict = dict(sorted(information.items(), key=lambda x: dt.strptime(x[0], '%d.%m.%Y %H:%M:%S')))
total_seconds = 0
for key, value in sorted_dict.items():
    print(f"\n{key}")
    for key_2, value_2 in value.items():
        print(f"   - {key_2}: {value_2}")
    total_seconds += float(value["duration"])
# Out:
# 23.12.2023 17:07:02
#    - time_date: 23.12.2023 17:07:02
#    - date: 23.12.2023
#    - time: 17:07:02
#    - n_commmands: 2
#    - duration: 27.296244
#
# 23.12.2023 17:09:26
#    - time_date: 23.12.2023 17:09:26
#    - date: 23.12.2023
#    - time: 17:09:26
#    - n_commmands: 2
#    - duration: 25.024813
#
# 23.12.2023 17:56:44
#    - time_date: 23.12.2023 17:56:44
#    - date: 23.12.2023
#    - time: 17:56:44
#    - n_commmands: 205
#    - duration: 2789.550049
#
# 23.12.2023 18:18:28
#    - time_date: 23.12.2023 18:18:28
#    - date: 23.12.2023
#    - time: 18:18:28
#    - n_commmands: 2
#    - duration: 24.385198

# %%
minutes, seconds = divmod(total_seconds, 60)
hours, minutes = divmod(minutes, 60)
days, hours = divmod(hours, 24)
print(f"Total traindata creation time:\n    -> {int(days)} Days\n    -> {int(hours)} Hours\n    -> {int(minutes)} Minutes\n    -> {int(seconds)} Seconds");
# Out:
# Total traindata creation time:
#     -> 0 Days
#     -> 0 Hours
#     -> 47 Minutes
#     -> 46 Seconds

# %% [markdown]
# **Command Stats:**

# %%
try:
    executed_commands = load_pickle("executed_commands")
except Exception:
    raise ValueError("No Log Files Yet!")

# %% [markdown]
# Runned Commands

# %%
count = 0
for key, value in executed_commands.items():
    count += value

print(f"Created {count} Training-Dialogs.")
# Out:
# Created 211 Training-Dialogs.

# %% [markdown]
# Unique Commands

# %%
[print(f"\n{'-'*16}\n{i}") for i in executed_commands.keys()];
# Out:
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: meadow
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: home
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: dinosaurs
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timetravel
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: past
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: dinosaurs
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: express
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: past
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timetravel
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: beachlake
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: medieval
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest-clearing
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: adventure park
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: clouds
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: north pole
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: meadow
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: north pole
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: meadow
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: home
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: flying
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: north pole
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: church
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: garden
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: church
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: flying
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: japanese-garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest-clearing
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: clouds
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: shopping-mall
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: medieval
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: church
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: mountain
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: meadow
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: flying
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: beachlake
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: medieval
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timetravel
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: beachlake
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: adventure park
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: shopping-mall
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: beachlake
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: past
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: mountain
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: adventure park
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest-clearing
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: japanese-garden
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: adventure park
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: clouds
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: flying
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest-clearing
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: japanese-garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: express
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: japanese-garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: mountain
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: dinosaurs
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: express
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet. The first message from the user is just the word other planet.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
#
# ----------------
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean. The first message from the user is just the word ocean.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...

# %% [markdown]
# All Commands

# %%
print("All executed Commands:")
sorted_commands = dict(sorted(executed_commands.items(), key=lambda x:x[1], reverse=False))
for key, value in sorted_commands.items():
    print(f"{'-'*16}\nAmount: {value}\nCommand:\n{key}")
# Out:
# All executed Commands:
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timetravel
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: express
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: north pole
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: meadow
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: church
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: flying
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: japanese-garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: clouds
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: shopping-mall
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: medieval
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: mountain
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: flying
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: shopping-mall
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: past
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: mountain
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: japanese-garden
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: adventure park
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: clouds
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest-clearing
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: japanese-garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: japanese-garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: mountain
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: dinosaurs
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: express
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet. The first message from the user is just the word other planet.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 1
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean. The first message from the user is just the word ocean.
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: meadow
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: dinosaurs
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: past
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: past
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timetravel
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: north pole
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: church
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: church
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: beachlake
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: medieval
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: timetravel
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: beachlake
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest-clearing
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: express
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 2
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: christmas
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: home
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: beachlake
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: adventure park
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: clouds
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: garden
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: home
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: flying
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: garden
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: adventure park
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: outer-space
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: adventure park
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: zoo
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: cave
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: flying
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 3
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: stream
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: dinosaurs
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: ocean
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: magic
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: medieval
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest-clearing
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: north pole
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of feeling in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: forest-clearing
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: meadow
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: hot-air-balloon
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of visualisation in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 4
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: beachlake
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: other planet
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: meadow
# It should be a meditative and calming story. A interactive mindful story with much details.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...
# ----------------
# Amount: 5
# Command:
# Create a dialog between 2 people. The first is the user and the other is the storyteller. The storyteller wants to create a interesting, exciting and calming story. The goal is to bring the user to positive thoughts and calm him a bit down.
# The topic of the story should be: castle
# It should be a meditative and calming story. A interactive mindful story with much details. And there can be some tasks of breathing in the story.
# Write only the Dialog no other message. Write the dialog on english and use following format:
# Person A: ...
# Person B: ...
# Person A: ...
# ...

# %% [markdown]
# ---
